# %% [markdown]
# ## RSS Ingestion Feed

# %% [markdown]
# ### Dependencies

# %% [markdown]
# ### Stage 1: Data Collection
#
#     - AWS Postgres DB.
#     - Schedule jobs for find relevant articles and save new ones to db
#     - Stock performance for **relevant** companies # might defer if apis exist
#
#
#
# ### Stage 2:
#     - Signal Generator: summary output + trailing gains/losses -> Forecast
#
#
#
# Once, a dataset has been compiled, curator, summarizer, and backtranslator can be trained

# %%
import feedparser

# Replace with your RSS feed URL
rss_url = 'https://news.google.com/rss/search?q=financial+news+us'

feed = feedparser.parse(rss_url)

print(len(feed))
for entry in feed.entries:
    print(entry.title)
    print(entry.link)
    print(entry.description)
    print('---')
# Out:
# 9
# Foot Locker's troubles much worse than feared, leading us to ... - CNBC
# https://news.google.com/rss/articles/CBMiamh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjMvMDgvMjMvZm9vdC1sb2NrZXJzLXRyb3VibGVzLW11Y2gtd29yc2UtdGhhbi1mZWFyZWQtbGVhZGluZy11cy10by1yZWV2YWx1YXRlLmh0bWzSAQA?oc=5
# <a href="https://news.google.com/rss/articles/CBMiamh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjMvMDgvMjMvZm9vdC1sb2NrZXJzLXRyb3VibGVzLW11Y2gtd29yc2UtdGhhbi1mZWFyZWQtbGVhZGluZy11cy10by1yZWV2YWx1YXRlLmh0bWzSAQA?oc=5" target="_blank">Foot Locker's troubles much worse than feared, leading us to ...</a>&nbsp;&nbsp;<font color="#6f6f6f">CNBC</font>
# ---
# Americans are shopping less. But the US economic engine is still ... - CNN
# https://news.google.?oc=5
# ...

# %%
## Selection Method
